# %% [markdown]
# <a href="https://colab.research.google.com/github/noahenifu9-png/Ihifix_AI-ML/blob/main/heart_disease_prediction_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Heart disease prediction system

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data collection and processing

# %%
#loading the csc data file to the pandas dataframe
heart_data = pd.read_csv('/content/heart_gtigwd.csv')

# %%
#print first row of the data set
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#print the last row of the data set
heart_data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
#number of rows and colums in the dataset
heart_data.shape
# Out:
# (1025, 14)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#checking for missing value
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#statistical measured about our data set
heart_data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
#checking the distribution of tatrget variable
heart_data['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# splitting features and target

# %%
x = heart_data.drop(columns='target', axis=1)
y = heart_data['target']

# %%
print(x)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %% [markdown]
# spliting the data into trainig data and test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (1025, 13) (820, 13) (205, 13)

# %% [markdown]
# Model training
#
# logistic regression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model evaluation

# %% [markdown]
# Accuracy score

# %%
# accuracy on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
print('Accuracy on training data : ', training_data_accuracy)
# Out:
# Accuracy on training data :  0.8524390243902439

# %% [markdown]
# Building a predictive system

# %%
input_data = (52, 1, 0, 125, 212, 0, 1, 168, 0, 1.0, 2, 2, 3)

#change the input data to a numpy array
imput_data_as_numpy_array = np.asarray(input_data)

input_data_reshaped = imput_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==0):
  print('The person does not have a heart disease')
else:
  print('The person has heart disease')
# Out:
# [0]
# The person does not have a heart disease
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# saving the train model

# %%
import pickle

# %%
filename ='heart_disease_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
#loading the saved model
loaded_model = pickle.load(open('heart_disease_model.sav', 'rb'))

# %%
for column in x.columns:
  print(column)
# Out:
# age
# sex
# cp
# trestbps
# chol
# fbs
# restecg
# thalach
# exang
# oldpeak
# slope
# ca
# thal

# %% [markdown]
# installing streamlit

# %%
# !pip install streamlit streamlit-option-menu pyngrok -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 62.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.3/829.3 kB 39.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 84.9 MB/s eta 0:00:00

# %%
import os, pickle

os.makedirs('saved_models', exist_ok=True)

# Save the heart disease model
pickle.dump(model, open('saved_models/heart_disease_model.pkl', 'wb'))

# Now, load the *same* heart disease model for verification or further use
with open('saved_models/heart_disease_model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

print("Model successfully loaded into 'loaded_model':", loaded_model)
# Out:
# Model successfully loaded into 'loaded_model': LogisticRegression()

# %% [markdown]
# APP.PY

# %%
import os
import pickle
import streamlit as st
from streamlit_option_menu import option_menu

st.set_page_config(page_title="Health assistant", page_icon=":heart:", layout="wide")

# Ensure the directory where models are saved is accessible relative to the script
# In Colab, you might need a different approach if __file__ doesn't point to a file on the mounted drive.
# For now, let's assume it's run from a context where 'saved_models' is directly accessible or adjust path.
# If running directly in Colab without specific file structure, you might use an absolute path or simplify.
# Let's adjust to load directly from 'saved_models/' assuming it's in the root of the Colab session or a mounted drive.
# This assumes 'saved_models' directory is at the same level as where the notebook is running or accessible.

# Corrected path for model loading in Colab environment if saved_models is at root
model_path = 'saved_models/heart_disease_model.pkl'
if not os.path.exists(model_path):
    # Fallback if the above path doesn't work and 'saved_models' is in the current working directory
    model_path = os.path.join(os.getcwd(), 'saved_models/heart_disease_model.pkl')

heart_disease_model = pickle.load(open(model_path, 'rb'))

with st.sidebar:
  selected = option_menu('disease prediction system',
                      ['Heart disease prediction'],
                      menu_icon="hospital-fill",
                      icons=['activity', 'heart', 'person'],
                      default_index=0)

#heart disease prediction page
if (selected == 'Heart disease prediction'):
  st.title('Heart disease prediction using ml ')
  col1, col2, col3 = st.columns(3)
  with col1:
    age = st.text_input('Age')
  with col2:
    sex = st.text_input('Sex')
  with col3:
    cp = st.text_input('Chest pain type')
  with col1:
    trestbps = st.text_input('Resting blood pressure')
  with col2:
    chol = st.text_input('Serum cholestoral in mg/dl')
# Out:
# 2026-06-18 11:48:30.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-18 11:48:30.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-18 11:48:30.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-18 11:48:30.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-18 11:48:30.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-18 11:48:30.219
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-06-18 11:48:30.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
from pyngrok import ngrok
# paste token
ngrok.set_auth_token('3FJCOWRj9p5gMcDddCyI4YVzG61_2sihcj36gcxYmuVgQWRoq')

# %%
# run streamlit
! streamlit run app.py &>/dev/null &

import time
time.sleep(3)  # wait for streamlit to start

#create public URL
public_url = ngrok.connect(8501)
print('Open your app here: ', public_url)
# Out:
# Open your app here:  NgrokTunnel: "https://yoyo-widely-liberty.ngrok-free.dev" -> "http://localhost:8501"
